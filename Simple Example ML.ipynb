# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.2.2-cp38-cp38-win_amd64.whl (8.3 MB)
# ...
#                                               0.0/42.2 MB ? eta -:--:--
#                                              0.0/42.2 MB 991.0 kB/s eta 0:00:43
#                                               0.1/42.2 MB 1.3 MB/s eta 0:00:33
#                                               0.2/42.2 MB 1.5 MB/s eta 0:00:29
#                                               0.4/42.2 MB 2.1 MB/s eta 0:00:20
#                                               0.6/42.2 MB 2.9 MB/s eta 0:00:15
#                                               0.9/42.2 MB 3.2 MB/s eta 0:00:14
#      -                                        1.2/42.2 MB 3.5 MB/s eta 0:00:12
#      -                                        1.4/42.2 MB 3.7 MB/s eta 0:00:11
#      -                                        1.6/42.2 MB 4.0 MB/s eta 0:00:11
#      -                                        1.9/42.2 MB 3.9 MB/s eta 0:00:11
# ...

# %%
 #2D Array (Height in Inches)
X= np.array([[60],[62],[64],[66],[68],[70],[72],[74],[76],[78]]) - 

#1D Array ( Weights in Pounds)
y=np.array([115, 120, 125, 130, 135, 140, 145, 150, 155, 160]) 

#Creating Instance of Linear Regression Function
model=LinearRegression() 

# Training Model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#Make Predictions
new_heights= np.array([[63],[67],[69]])
pred_weights =  model.predict(new_heights)

# Print
print(pred_weights)
# Out:
# [122.5 132.5 137.5]
